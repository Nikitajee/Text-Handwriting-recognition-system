# %%
import tkinter as tk
from tkinter import *

from tkinter import messagebox as msg
from tkinter import ttk
import mysql.connector
################################### importing scripts

################################### lib to perform CRUD operations in csv/excel
from PIL import Image, ImageTk
from openpyxl import *
import pandas as pd
import numpy as np
import cv2,os
from cv2 import cvtColor
import csv
################################### other dependencies
import datetime
from time import strftime
from datetime import datetime
import os
root=tk.Toplevel()
root.title("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@WELCOME TO MY HANDWRITINY@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
root.geometry("1530x790+0+0")


# title
title=Label(root,text="@@@@!!!Handwriting Text Recognition & Text To Handwriting Recognition!!!@@@@",font=("times new roman",30,"bold"),bg="#330000",fg="white")
title.place(x=0,y=0,width=1530,height=45)

# bg image
image3 = Image.open(r"image/image13.jpg")
image3=image3.resize((1530,580), Image.ANTIALIAS)
photo3 = ImageTk.PhotoImage(image3)
bg=Label(root,image=photo3)
bg.place(x=0,y=45,width=1530,height=580)

# Digit & Character

image4 = Image.open(r"image/image17.png")
image4=image4.resize((200,200), Image.ANTIALIAS)
photo4 = ImageTk.PhotoImage(image4)

b1=Button(bg,image=photo4,cursor="hand2")
b1.place(x=150,y=50,width=200,height=200)
b1_1=Button(bg,text="*Digit & Character*",cursor="hand2",activebackground="lightpink",font=("times new roman",15,"bold"),bg="#330000",fg="white")
b1_1.place(x=150,y=230,width=200,height=40)

# Text to Handwritten

image5 = Image.open(r"image/image21.png")
image5=image5.resize((200,200), Image.ANTIALIAS)
photo5 = ImageTk.PhotoImage(image5)

b1=Button(bg,image=photo5,cursor="hand2")
b1.place(x=500,y=50,width=200,height=200)

b1_1=Button(bg,text="*Text to Handwritten*",cursor="hand2",activebackground="lightpink",font=("times new roman",15,"bold"),bg="#330000",fg="white")
b1_1.place(x=500,y=230,width=200,height=40)

# Image To Text

image6 = Image.open(r"image/image8.jpg")
image6=image6.resize((200,200), Image.ANTIALIAS)
photo6= ImageTk.PhotoImage(image6)

b1=Button(bg,image=photo6,cursor="hand2")
b1.place(x=850,y=50,width=200,height=200)

b1_1=Button(bg,text="*Image To Text*",cursor="hand2",activebackground="lightpink",font=("times new roman",15,"bold"),bg="#330000",fg="white")
b1_1.place(x=850,y=230,width=200,height=40)

# Text Editor

image7 = Image.open(r"image/image14.png")
image7=image7.resize((200,200), Image.ANTIALIAS)
photo7= ImageTk.PhotoImage(image7)

b1=Button(bg,image=photo7,cursor="hand2")
b1.place(x=1200,y=50,width=200,height=200)

b1_1=Button(bg,text="*Text Editor*",cursor="hand2",activebackground="lightpink",font=("times new roman",15,"bold"),bg="#330000",fg="white")
b1_1.place(x=1200,y=230,width=200,height=40)

# All Language Change

image8 = Image.open(r"image/image20.png")
image8=image8.resize((200,200), Image.ANTIALIAS)
photo8= ImageTk.PhotoImage(image8)

b1=Button(bg,image=photo8,cursor="hand2")
b1.place(x=325,y=300,width=200,height=200)

b1_1=Button(bg,text="*All Language Change*",cursor="hand2",activebackground="lightpink",font=("times new roman",14,"bold"),bg="#330000",fg="white")
b1_1.place(x=325,y=480,width=200,height=40)

# Text To Speech

image10 = Image.open(r"image/image25.png")
image10=image10.resize((200,200), Image.ANTIALIAS)
photo10= ImageTk.PhotoImage(image10)

b1=Button(bg,image=photo10,cursor="hand2")
b1.place(x=675,y=300,width=200,height=200)

b1_1=Button(bg,text="*Text To Speech*",cursor="hand2",activebackground="lightpink",font=("times new roman",15,"bold"),bg="#330000",fg="white")
b1_1.place(x=675,y=480,width=200,height=40)

# Exit Desk

image11 = Image.open(r"image/image23.png")
image11=image11.resize((200,200), Image.ANTIALIAS)
photo11= ImageTk.PhotoImage(image11)

b1=Button(bg,image=photo11,cursor="hand2")
b1.place(x=1025,y=300,width=200,height=200)

b1_1=Button(bg,text="*Exit*",cursor="hand2",activebackground="lightpink",font=("times new roman",15,"bold"),bg="#330000",fg="white")
b1_1.place(x=1025,y=480,width=200,height=40)

title=Label(root,text="*********************************************************************************************************************************************************",font=("times new roman",15,"bold"),bg="#330000",fg="white")
title.place(x=0,y=625,width=1530,height=15)

# down image

image = Image.open(r"image/image11.jpg")
image=image.resize((510,165), Image.ANTIALIAS)
photo = ImageTk.PhotoImage(image)
f1=Label(root,image=photo)
f1.place(x=0,y=640,width=510,height=165)

image1 = Image.open(r"image/image12.jpg")
image1=image1.resize((510,165), Image.ANTIALIAS)
photo1 = ImageTk.PhotoImage(image1)
f1=Label(root,image=photo1)
f1.place(x=510,y=640,width=510,height=165)

image2 = Image.open(r"image/image11.jpg")
image2=image2.resize((510,165), Image.ANTIALIAS)
photo2 = ImageTk.PhotoImage(image2)
f1=Label(root,image=photo2)
f1.place(x=1020,y=640,width=510,height=165)

    
root.mainloop()
